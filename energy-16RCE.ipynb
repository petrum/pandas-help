# %%
# %matplotlib inline
import pandas as pd

pd.read_csv('/home/petrum/tmp/rce16.csv', parse_dates=[0], names=['time', 'id', 'usage'], usecols=[0, 3, 7], index_col=1).ix[20183568].set_index('time').plot()
